# %% [markdown]
# <a href="https://colab.research.google.com/github/srievarshika/Data-Analytics-and-Visualization/blob/main/%20%20davexp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
print("NumPy Version:", np.__version__)

import pandas as pd
print("Pandas Version:", pd.__version__)

import matplotlib
print("Matplotlib Version:", matplotlib.__version__)

import seaborn as sns
print("Seaborn Version:", sns.__version__)

import statsmodels
print("Statsmodels Version:", statsmodels.__version__)

import scipy
print("SciPy Version:", scipy.__version__)

import plotly
print("Plotly Version:", plotly.__version__)

import bokeh
print("Bokeh Version:", bokeh.__version__)
# Out:
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Matplotlib Version: 3.10.0
# Seaborn Version: 0.13.2
# Statsmodels Version: 0.14.6
# SciPy Version: 1.16.3
# Plotly Version: 5.24.1
# Bokeh Version: 3.8.2
